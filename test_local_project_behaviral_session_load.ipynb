# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.patches import Patch
import seaborn as sns
from allensdk.brain_observatory.behavior.behavior_project_cache import VisualBehaviorNeuropixelsProjectCache

sns.set_style('ticks')

# %%
drive_dir = "/Volumes/Brain2024"
cache = VisualBehaviorNeuropixelsProjectCache.from_local_cache(cache_dir=drive_dir, use_static_cache=True)

# %%
behavior_sessions = cache.get_behavior_session_table()

# %%
sub_sessions = behavior_sessions[behavior_sessions['genotype']== 'wt/wt']

# %%
sub_sessions[937:].head()
# Out:
#                     equipment_name genotype  mouse_id sex  age_in_days  \
# behavior_session_id
# 1044408432                    NP.1    wt/wt    524761   F          151
# 1044624428                    NP.1    wt/wt    524761   F          152
# 1052162536                    NP.1    wt/wt    524760   F          180
# 1056528863                    NP.1    wt/wt    531237   F          165
# 1056746264                    NP.1    wt/wt    531237   F          166
#
#                      session_number  prior_exposures_to_session_type  \
# behavior_session_id
# 1044408432                       47                                0
# 1044624428                       48                                0
# 1052162536                       58                                0
# 1056528863                       50                                0
# 1056746264                       51                                0
#
#                      prior_exposures_to_image_set  \
# behavior_session_id
# 1044408432                                     30
# 1044624428                                      0
# 1052162536                                      0
# 1056528863                                     43
# 1056746264                                      0
#
#                      prior_exposures_to_omissions  ecephys_session_id  \
# behavior_session_id
# 1044408432                                      0          1044385384
# 1044624428                                      1          1044594870
# 1052162536                                      1          1051155866
# 1056528863                                      0          1056495334
# 1056746264                                      1          1056720277
#
#                                   date_of_acquisition  \
# behavior_session_id
# 1044408432           2020-08-19 14:47:08.574000+00:00
# 1044624428           2020-08-20 15:03:56.422000+00:00
# 1052162536           2020-09-17 15:05:39.665000+00:00
# 1056528863           2020-10-14 15:11:39.817000+00:00
# 1056746264           2020-10-15 14:23:49.277000+00:00
#
#                                     session_type image_set  file_id
# behavior_session_id
# 1044408432           EPHYS_1_images_G_5uL_reward         G     -999
# 1044624428           EPHYS_1_images_H_5uL_reward         H     -999
# 1052162536           EPHYS_1_images_H_3uL_reward         H     -999
# 1056528863           EPHYS_1_images_G_3uL_reward         G     -999
# 1056746264           EPHYS_1_images_H_3uL_reward         H     -999

# %%
# this is a mouse with recording:
behavior_session_id = 1044408432
behavior_session = cache.get_behavior_session(behavior_session_id)
# Out:
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)

# %%
sub_sessions[:937].head()
# Out:
#                     equipment_name genotype  mouse_id sex  age_in_days  \
# behavior_session_id
# 1040427027                    NP.0    wt/wt    524761   F          135
# 1041062571                    NP.0    wt/wt    524761   F          137
# 1042055457                    NP.0    wt/wt    524761   F          142
# 1043697372                    NP.1    wt/wt    524761   F          149
# 1040846423                    NP.1    wt/wt    524761   F          136
#
#                      session_number  prior_exposures_to_session_type  \
# behavior_session_id
# 1040427027                       35                                0
# 1041062571                       37                                2
# 1042055457                       40                                5
# 1043697372                       45                               10
# 1040846423                       36                                1
#
#                      prior_exposures_to_image_set  \
# behavior_session_id
# 1040427027                                     18
# 1041062571                                     20
# 1042055457                                     23
# 1043697372                                     28
# 1040846423                                     19
#
#                      prior_exposures_to_omissions  ecephys_session_id  \
# behavior_session_id
# 1040427027                                      0          1040386931
# 1041062571                                      0          1041048883
# 1042055457                                      0          1042017828
# 1043697372                                      0          1043669369
# 1040846423                                      0          1040834687
#
#                                   date_of_acquisition  \
# behavior_session_id
# 1040427027           2020-08-03 12:03:32.560000+00:00
# 1041062571           2020-08-05 09:26:26.515000+00:00
# 1042055457           2020-08-10 14:38:20.389000+00:00
# 1043697372           2020-08-17 11:28:17.793000+00:00
# 1040846423           2020-08-04 12:07:54.232000+00:00
#
#                                                         session_type  \
# behavior_session_id
# 1040427027           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1041062571           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1042055457           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1043697372           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1040846423           HABITUATION_5_images_G_handoff_ready_5uL_reward
#
#                     image_set  file_id
# behavior_session_id
# 1040427027                  G     1236
# 1041062571                  G     1237
# 1042055457                  G     1238
# 1043697372                  G     1239
# 1040846423                  G     1240

# %%
# this is a behavior session with out recording:
behavior_session_id = 1040427027
behavior_session = cache.get_behavior_session(behavior_session_id)
