# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from allensdk.brain_observatory.behavior.behavior_project_cache import VisualBehaviorNeuropixelsProjectCache

# %% [markdown]
# ### Create cache

# %%
drive_dir = "/Volumes/Brain2024"
cache = VisualBehaviorNeuropixelsProjectCache.from_local_cache(cache_dir=drive_dir, use_static_cache=True)

# %%
cache.list_manifest_file_names() # Okay we just load the latest version
# Out:
# ['visual-behavior-neuropixels_project_manifest_v0.5.0.json']

# %%
behavior_sessions = cache.get_behavior_session_table()

# %%
behavior_sessions = cache.get_behavior_session_table()
print(f"Total number of behavior sessions: {len(behavior_sessions)}")

print()
types = behavior_sessions.session_type.unique()
print("Unique types of sessions (Training/Recording):")
print()
for i, session_type in enumerate(types, start=1):
    print(f"{i}. {session_type}")
# Out:
# Total number of behavior sessions: 3424
#
# Unique types of sessions (Training/Recording):
#
# 1. HABITUATION_5_images_G_handoff_ready_5uL_reward
# 2. TRAINING_1_gratings
# 3. TRAINING_2_gratings_flashed
# 4. TRAINING_5_images_G_epilogue
# 5. TRAINING_3_images_G_10uL_reward
# 6. TRAINING_4_images_G_training
# 7. TRAINING_0_gratings_autorewards_15min
# 8. HABITUATION_5_images_G_handoff_ready_3uL_reward
# 9. TRAINING_5_images_G_handoff_ready_5uL_reward
# 10. TRAINING_4_images_G_training_7uL_reward
# 11. TRAINING_2_gratings_flashed_10uL_reward
# 12. TRAINING_1_gratings_10uL_reward
# 13. TRAINING_0_gratings_autorewards_15min_0uL_reward
# 14. TRAINING_5_images_G_epilogue_5uL_reward
# 15. EPHYS_1_images_G_3uL_reward
# 16. TRAINING_5_images_G_handoff_lapsed_5uL_reward
# 17. EPHYS_1_images_H_3uL_reward
# 18. HABITUATION_5_images_H_handoff_ready_5uL_reward
# 19. HABITUATION_5_images_H_handoff_ready_3uL_reward
# 20. TRAINING_5_images_H_handoff_ready_5uL_reward
# 21. TRAINING_3_images_H_10uL_reward
# 22. TRAINING_4_images_H_training_7uL_reward
# 23. TRAINING_5_images_H_epilogue_5uL_reward
# 24. TRAINING_5_images_H_handoff_lapsed_5uL_reward
# 25. EPHYS_1_images_G_5uL_reward
# 26. EPHYS_1_images_H_5uL_reward

# %%
types = behavior_sessions.session_type.unique()
print("Unique types of EPHYS sessions:")
print()
ephys_types = [session_type for session_type in types if 'EPHYS' in session_type]

for i, session_type in enumerate(ephys_types, start=1):
    print(f"{i}. {session_type}")
# Out:
# Unique types of EPHYS sessions:
#
# 1. EPHYS_1_images_G_3uL_reward
# 2. EPHYS_1_images_H_3uL_reward
# 3. EPHYS_1_images_G_5uL_reward
# 4. EPHYS_1_images_H_5uL_reward

# %% [markdown]
# ### Get access to behaviral data

# %%
# load example mice

mouse_id = 506940
print('Number of behaviral sessions for an example mouse:', len(behavior_sessions[behavior_sessions['mouse_id']== mouse_id]))
# Out:
# Number of behaviral sessions for an example mouse: 27

# %%
behavior_sessions_example_mouse = behavior_sessions[behavior_sessions['mouse_id']== mouse_id]

# %%
behavior_sessions_example_mouse
# Out:
#                     equipment_name  \
# behavior_session_id
# 1040882886                    NP.1
# 1042886405                    NP.0
# 1042328825                    NP.0
# 1041062566                    NP.1
# 1042578564                    NP.0
# 1043159973                    NP.0
# 1012862460              BEH.B-Box1
# 1014008383              BEH.B-Box1
# 1013316467              BEH.B-Box1
# 1013822615              BEH.B-Box1
# 1015591626              BEH.B-Box1
# 1011600362              BEH.G-Box1
# 1041272851                    NP.1
# 1041487615                    NP.0
# 1013477094              BEH.B-Box1
# 1013651495              BEH.B-Box1
# 1014456264              BEH.B-Box1
# 1014654623              BEH.B-Box1
# 1014864789              BEH.B-Box1
# 1015019342              BEH.B-Box1
# 1015173833              BEH.B-Box1
# 1010991549              BEH.G-Box1
# 1011894888              BEH.G-Box1
# 1012271345              BEH.G-Box1
# 1012608280              BEH.G-Box1
# 1043788445                    NP.1
# 1044048872                    NP.1
#
#                                                           genotype  mouse_id  \
# behavior_session_id
# 1040882886           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1042886405           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1042328825           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1041062566           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1042578564           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1043159973           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1012862460           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1014008383           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1013316467           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1013822615           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1015591626           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1011600362           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1041272851           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1041487615           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1013477094           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1013651495           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1014456264           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1014654623           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1014864789           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1015019342           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1015173833           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1010991549           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1011894888           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1012271345           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1012608280           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1043788445           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
# 1044048872           Vip-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt    506940
#
#                     sex  age_in_days  session_number  \
# behavior_session_id
# 1040882886            M          253              18
# 1042886405            M          262              24
# 1042328825            M          260              22
# 1041062566            M          254              19
# 1042578564            M          261              23
# 1043159973            M          263              25
# 1012862460            M          102               6
# 1014008383            M          109              11
# 1013316467            M          105               7
# 1013822615            M          108              10
# 1015591626            M          119              17
# 1011600362            M           98               2
# 1041272851            M          255              20
# 1041487615            M          256              21
# 1013477094            M          106               8
# 1013651495            M          107               9
# 1014456264            M          112              12
# 1014654623            M          113              13
# 1014864789            M          114              14
# 1015019342            M          115              15
# 1015173833            M          116              16
# 1010991549            M           95               1
# 1011894888            M           99               3
# 1012271345            M          100               4
# 1012608280            M          101               5
# 1043788445            M          266              26
# 1044048872            M          267              27
#
#                      prior_exposures_to_session_type  \
# behavior_session_id
# 1040882886                                         0
# 1042886405                                         6
# 1042328825                                         4
# 1041062566                                         1
# 1042578564                                         5
# 1043159973                                         7
# 1012862460                                         4
# 1014008383                                         3
# 1013316467                                         5
# 1013822615                                         2
# 1015591626                                         3
# 1011600362                                         0
# 1041272851                                         2
# 1041487615                                         3
# 1013477094                                         0
# 1013651495                                         1
# 1014456264                                         0
# 1014654623                                         0
# 1014864789                                         0
# 1015019342                                         1
# 1015173833                                         2
# 1010991549                                         0
# 1011894888                                         1
# 1012271345                                         2
# 1012608280                                         3
# 1043788445                                         0
# 1044048872                                         0
#
#                      prior_exposures_to_image_set  \
# behavior_session_id
# 1040882886                                      6
# 1042886405                                     12
# 1042328825                                     10
# 1041062566                                      7
# 1042578564                                     11
# 1043159973                                     13
# 1012862460                                   <NA>
# 1014008383                                   <NA>
# 1013316467                                   <NA>
# 1013822615                                   <NA>
# 1015591626                                      5
# 1011600362                                   <NA>
# 1041272851                                      8
# 1041487615                                      9
# 1013477094                                   <NA>
# 1013651495                                   <NA>
# 1014456264                                      0
# 1014654623                                      1
# 1014864789                                      2
# 1015019342                                      3
# 1015173833                                      4
# 1010991549                                   <NA>
# 1011894888                                   <NA>
# 1012271345                                   <NA>
# 1012608280                                   <NA>
# 1043788445                                     14
# 1044048872                                      0
#
#                      prior_exposures_to_omissions  ecephys_session_id  \
# behavior_session_id
# 1040882886                                      0          1040871931
# 1042886405                                      0          1042863451
# 1042328825                                      0          1042309765
# 1041062566                                      0          1041050914
# 1042578564                                      0          1042566236
# 1043159973                                      0          1043148091
# 1012862460                                      0                <NA>
# 1014008383                                      0                <NA>
# 1013316467                                      0                <NA>
# 1013822615                                      0                <NA>
# 1015591626                                      0                <NA>
# 1011600362                                      0                <NA>
# 1041272851                                      0                <NA>
# 1041487615                                      0                <NA>
# 1013477094                                      0                <NA>
# 1013651495                                      0                <NA>
# 1014456264                                      0                <NA>
# 1014654623                                      0                <NA>
# 1014864789                                      0                <NA>
# 1015019342                                      0                <NA>
# 1015173833                                      0                <NA>
# 1010991549                                      0                <NA>
# 1011894888                                      0                <NA>
# 1012271345                                      0                <NA>
# 1012608280                                      0                <NA>
# 1043788445                                      0          1043752325
# 1044048872                                      1          1044016459
#
#                                   date_of_acquisition  \
# behavior_session_id
# 1040882886           2020-08-04 16:30:32.835000+00:00
# 1042886405           2020-08-13 16:45:10.869000+00:00
# 1042328825           2020-08-11 13:38:10.476000+00:00
# 1041062566           2020-08-05 09:27:22.482000+00:00
# 1042578564           2020-08-12 13:13:12.237000+00:00
# 1043159973           2020-08-14 15:09:56.657000+00:00
# 1012862460           2020-03-06 12:36:40.378000+00:00
# 1014008383           2020-03-13 13:51:47.783000+00:00
# 1013316467           2020-03-09 12:52:35.332000+00:00
# 1013822615           2020-03-12 13:12:43.481000+00:00
# 1015591626           2020-03-23 10:20:16.160000+00:00
# 1011600362           2020-03-02 10:21:59.096000+00:00
# 1041272851           2020-08-06 11:08:49.350000+00:00
# 1041487615           2020-08-07 11:46:28.205000+00:00
# 1013477094           2020-03-10 13:02:32.863000+00:00
# 1013651495           2020-03-11 14:08:01.287000+00:00
# 1014456264           2020-03-16 15:16:25.163000+00:00
# 1014654623           2020-03-17 15:18:06.777000+00:00
# 1014864789           2020-03-18 14:51:05.621000+00:00
# 1015019342           2020-03-19 14:33:53.405000+00:00
# 1015173833           2020-03-20 14:47:44.485000+00:00
# 1010991549           2020-02-28 11:11:17.576000+00:00
# 1011894888           2020-03-03 10:08:53.396000+00:00
# 1012271345           2020-03-04 10:13:31.434000+00:00
# 1012608280           2020-03-05 10:09:47.099000+00:00
# 1043788445           2020-08-17 15:21:49.664000+00:00
# 1044048872           2020-08-18 16:08:19.974000+00:00
#
#                                                         session_type  \
# behavior_session_id
# 1040882886           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1042886405           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1042328825           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1041062566           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1042578564           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1043159973           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1012862460                                       TRAINING_1_gratings
# 1014008383                               TRAINING_2_gratings_flashed
# 1013316467                                       TRAINING_1_gratings
# 1013822615                               TRAINING_2_gratings_flashed
# 1015591626                              TRAINING_5_images_G_epilogue
# 1011600362                                       TRAINING_1_gratings
# 1041272851           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1041487615           HABITUATION_5_images_G_handoff_ready_5uL_reward
# 1013477094                               TRAINING_2_gratings_flashed
# 1013651495                               TRAINING_2_gratings_flashed
# 1014456264                           TRAINING_3_images_G_10uL_reward
# 1014654623                              TRAINING_4_images_G_training
# 1014864789                              TRAINING_5_images_G_epilogue
# 1015019342                              TRAINING_5_images_G_epilogue
# 1015173833                              TRAINING_5_images_G_epilogue
# 1010991549                     TRAINING_0_gratings_autorewards_15min
# 1011894888                                       TRAINING_1_gratings
# 1012271345                                       TRAINING_1_gratings
# 1012608280                                       TRAINING_1_gratings
# 1043788445                               EPHYS_1_images_G_5uL_reward
# 1044048872                               EPHYS_1_images_H_5uL_reward
#
#                     image_set  file_id
# behavior_session_id
# 1040882886                  G     1022
# 1042886405                  G     1023
# 1042328825                  G     1024
# 1041062566                  G     1025
# 1042578564                  G     1026
# 1043159973                  G     1027
# 1012862460                NaN     1028
# 1014008383                NaN     1029
# 1013316467                NaN     1030
# 1013822615                NaN     1031
# 1015591626                  G     1032
# 1011600362                NaN     1033
# 1041272851                  G     1034
# 1041487615                  G     1035
# 1013477094                NaN     1036
# 1013651495                NaN     1037
# 1014456264                  G     1038
# 1014654623                  G     1039
# 1014864789                  G     1040
# 1015019342                  G     1041
# 1015173833                  G     1042
# 1010991549                NaN     1043
# 1011894888                NaN     1044
# 1012271345                NaN     1045
# 1012608280                NaN     1046
# 1043788445                  G     -999
# 1044048872                  H     -999

# %% [markdown]
# #### Get behavior trials directly from `cache.get_behavior_session()`

# %% [markdown]
# _Can get it from the ecephys_session:_

# %%
# ecephys_session_id
session_id = 1053941483 
session = cache.get_ecephys_session(session_id)
metadata = session.metadata
metadata
# Out:
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# {'equipment_name': 'NP.1',
#  'sex': 'M',
#  'age_in_days': 180,
#  'stimulus_frame_rate': 60.0,
#  'session_type': 'EPHYS_1_images_H_3uL_reward',
#  'date_of_acquisition': datetime.datetime(2020, 10, 2, 0, 3, 58, tzinfo=tzutc()),
#  'reporter_line': 'Ai32(RCL-ChR2(H134R)_EYFP)',
#  'cre_line': 'Sst-IRES-Cre',
#  'behavior_session_uuid': UUID('330937b4-ec9e-4bc4-8567-f74666f52596'),
#  'driver_line': ['Sst-IRES-Cre'],
#  'mouse_id': '527749',
#  'project_code': 'Not Available',
#  'full_genotype': 'Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt',
#  'behavior_session_id': 1053960987,
#  'ecephys_session_id': 1053941483}

# %%
trials = session.trials
trials.head()
# Out:
#            start_time  stop_time initial_image_name change_image_name  \
# trials_id
# 0            25.20983   26.19343            im104_r           im104_r
# 1            26.71046   28.34528            im104_r           im104_r
# 2            28.96234   32.73245            im104_r           im104_r
# 3            33.46618   35.85175            im104_r           im104_r
# 4            36.46863   39.62138            im104_r           im104_r
#
#            is_change  change_time_no_display_delay     go  catch  \
# trials_id
# 0              False                           NaN  False  False
# 1              False                           NaN  False  False
# 2              False                           NaN  False  False
# 3              False                           NaN  False  False
# 4              False                           NaN  False  False
#
#                      lick_times  response_time  reward_time  reward_volume  \
# trials_id
# 0          [25.72637, 25.87602]            NaN          NaN            0.0
# 1                    [28.02817]            NaN          NaN            0.0
# 2                    [32.39844]            NaN          NaN            0.0
# 3                    [35.53463]            NaN          NaN            0.0
# 4          [39.15441, 39.28716]            NaN          NaN            0.0
#
#              hit  false_alarm   miss  correct_reject  aborted  auto_rewarded  \
# trials_id
# 0          False        False  False           False     True          False
# 1          False        False  False           False     True          False
# 2          False        False  False           False     True          False
# 3          False        False  False           False     True          False
# 4          False        False  False           False     True          False
#
#            change_frame  trial_length
# trials_id
# 0                   -99       0.98360
# 1                   -99       1.63482
# 2                   -99       3.77011
# 3                   -99       2.38557
# 4                   -99       3.15275

# %%
trials.tail()
# Out:
#            start_time   stop_time initial_image_name change_image_name  \
# trials_id
# 595        3611.49208  3618.76483            im083_r           im024_r
# 596        3618.99803  3619.59865            im024_r           im024_r
# 597        3619.74882  3622.36770            im024_r           im024_r
# 598        3622.75138  3623.11829            im024_r           im024_r
# 599        3623.50198  3631.50933            im024_r           im024_r
#
#            is_change  change_time_no_display_delay     go  catch  \
# trials_id
# 595             True                    3614.49490   True  False
# 596            False                           NaN  False  False
# 597            False                           NaN  False  False
# 598            False                           NaN  False  False
# 599            False                    3627.25499  False   True
#
#                                                   lick_times  response_time  \
# trials_id
# 595        [3614.97902, 3615.11108, 3615.22784, 3615.3446...     3614.97902
# 596                                             [3619.28223]            NaN
# 597        [3621.73408, 3621.83335, 3621.9336, 3622.06724...            NaN
# 598                                 [3622.81796, 3623.23466]            NaN
# 599                                                       []            NaN
#
#            reward_time  reward_volume    hit  false_alarm   miss  \
# trials_id
# 595         3614.97902          0.003   True        False  False
# 596                NaN          0.000  False        False  False
# 597                NaN          0.000  False        False  False
# 598                NaN          0.000  False        False  False
# 599                NaN          0.000  False        False  False
#
#            correct_reject  aborted  auto_rewarded  change_frame  trial_length
# trials_id
# 595                 False    False          False        215234       7.27275
# 596                 False     True          False           -99       0.60062
# 597                 False     True          False           -99       2.61888
# 598                 False     True          False           -99       0.36691
# 599                  True    False          False        215999       8.00735

# %% [markdown]
# _or frome the behavior_session directly:_

# %%
behavior_session_id = metadata['behavior_session_id']

# %%
behavior_session = cache.get_behavior_session(behavior_session_id)
# Out:
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)

# %%
behavior_session.trials.head()
# Out:
#            start_time  stop_time initial_image_name change_image_name  \
# trials_id
# 0            25.20983   26.19343            im104_r           im104_r
# 1            26.71046   28.34528            im104_r           im104_r
# 2            28.96234   32.73245            im104_r           im104_r
# 3            33.46618   35.85175            im104_r           im104_r
# 4            36.46863   39.62138            im104_r           im104_r
#
#            is_change  change_time_no_display_delay     go  catch  \
# trials_id
# 0              False                           NaN  False  False
# 1              False                           NaN  False  False
# 2              False                           NaN  False  False
# 3              False                           NaN  False  False
# 4              False                           NaN  False  False
#
#                      lick_times  response_time  reward_time  reward_volume  \
# trials_id
# 0          [25.72637, 25.87602]            NaN          NaN            0.0
# 1                    [28.02817]            NaN          NaN            0.0
# 2                    [32.39844]            NaN          NaN            0.0
# 3                    [35.53463]            NaN          NaN            0.0
# 4          [39.15441, 39.28716]            NaN          NaN            0.0
#
#              hit  false_alarm   miss  correct_reject  aborted  auto_rewarded  \
# trials_id
# 0          False        False  False           False     True          False
# 1          False        False  False           False     True          False
# 2          False        False  False           False     True          False
# 3          False        False  False           False     True          False
# 4          False        False  False           False     True          False
#
#            change_frame  trial_length
# trials_id
# 0                   -99       0.98360
# 1                   -99       1.63482
# 2                   -99       3.77011
# 3                   -99       2.38557
# 4                   -99       3.15275

# %% [markdown]
# <span style="color:orange">__Notes__:</span> that `trails` do not contain information about the the stimulus content

# %%
trials.columns
# Out:
# Index(['start_time', 'stop_time', 'initial_image_name', 'change_image_name',
#        'is_change', 'change_time_no_display_delay', 'go', 'catch',
#        'lick_times', 'response_time', 'reward_time', 'reward_volume', 'hit',
#        'false_alarm', 'miss', 'correct_reject', 'aborted', 'auto_rewarded',
#        'change_frame', 'trial_length'],
#       dtype='object')

# %% [markdown]
# It's the same thing!

# %%
num_licks = len(behavior_session.licks) 
print("Total number of licks (not lick bout):", num_licks)
# Out:
# Total number of licks (not lick bout): 2990

# %%
behavior_session.get_performance_metrics()
# Out:
# {'trial_count': 600,
#  'go_trial_count': 295,
#  'catch_trial_count': 44,
#  'hit_trial_count': 139,
#  'miss_trial_count': 156,
#  'false_alarm_trial_count': 1,
#  'correct_reject_trial_count': 43,
#  'auto_reward_count': 3,
#  'earned_reward_count': 139,
#  'total_reward_count': 142,
#  'total_reward_volume': 0.43199999999999994,
#  'maximum_reward_rate': 5.033826263778787,
#  'engaged_trial_count': 440,
#  'mean_hit_rate': 0.47388024381123905,
#  'mean_hit_rate_uncorrected': 0.4765842752763324,
#  'mean_hit_rate_engaged': 0.535890015217069,
#  'mean_false_alarm_rate': 0.06851317111891128,
#  'mean_false_alarm_rate_uncorrected': 0.02273562288668029,
#  'mean_false_alarm_rate_engaged': 0.06896672016964904,
#  'mean_dprime': 1.4274968629298022,
#  'mean_dprime_engaged': 1.6116689051369812,
#  'max_dprime': 2.2015497100616526,
#  'max_dprime_engaged': 2.2015497100616526}

# %%
len(behavior_session.get_reward_rate()) # how is this defined? (for every trail actually)
# Out:
# 600

# %% [markdown]
# ### Maybe also useful, stimulus table

# %%
stim_table = behavior_session.stimulus_presentations

# %%
len(stim_table)
print("How many stimulus presentations in session?", len(stim_table))
# Out:
# How many stimulus presentations in session? 13405

# %%
stim_table.head()
# Out:
#                            stimulus_block image_name  duration  start_time  \
# stimulus_presentations_id
# 0                                       0    im104_r  0.250212   25.254420
# 1                                       0    im104_r  0.250212   26.005057
# 2                                       0    im104_r  0.250208   26.755685
# 3                                       0    im104_r  0.250207   27.506307
# 4                                       0    im104_r  0.250213   28.256929
#
#                             end_time  start_frame  end_frame  is_change  \
# stimulus_presentations_id
# 0                          25.504632           60         75      False
# 1                          26.255269          105        120      False
# 2                          27.005892          150        165      False
# 3                          27.756515          195        210      False
# 4                          28.507142          240        255      False
#
#                            is_image_novel  omitted  ...  spatial_frequency  \
# stimulus_presentations_id                           ...
# 0                                    True    False  ...                NaN
# 1                                    True    False  ...                NaN
# 2                                    True    False  ...                NaN
# 3                                    True    False  ...                NaN
# 4                                    True    False  ...                NaN
#
#                            color rewarded  orientation  temporal_frequency  \
# stimulus_presentations_id
# 0                            NaN    False          NaN                 NaN
# 1                            NaN    False          NaN                 NaN
# 2                            NaN    False          NaN                 NaN
# 3                            NaN    False          NaN                 NaN
# 4                            NaN    False          NaN                 NaN
#
#                            active  position_x  contrast  is_sham_change  \
# stimulus_presentations_id
# 0                            True         NaN       NaN           False
# 1                            True         NaN       NaN           False
# 2                            True         NaN       NaN           False
# 3                            True         NaN       NaN           False
# 4                            True         NaN       NaN           False
#
#                            stimulus_index
# stimulus_presentations_id
# 0                                     -99
# 1                                     -99
# 2                                     -99
# 3                                     -99
# 4                                     -99
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Visualize behavior trial data on raster plot

# %%
raster_start_time = 407
raster_end_time = 427
