# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.patches import Patch
import seaborn as sns
from allensdk.brain_observatory.behavior.behavior_project_cache import VisualBehaviorNeuropixelsProjectCache
import psytrack as psy
import os

sns.set_style('ticks')

import src_local.utils as utils
import src_local.get_metrics as get_metrics
import src_local.format_Xy as format_Xy
import src_local.psy_funcs as psy_funcs

# %%
drive_dir = "/Volumes/Brain2024"
cache = VisualBehaviorNeuropixelsProjectCache.from_local_cache(cache_dir=drive_dir, use_static_cache=True)

behavior_sessions = cache.get_behavior_session_table()

# %%
subset_sessions = behavior_sessions[
    (behavior_sessions.session_type.str.contains('TRAINING_4')) & 
    (behavior_sessions.genotype == 'wt/wt')]

# %%
# subset_sessions = behavior_sessions[
#     (behavior_sessions.session_type.str.contains('TRAINING_5')) & 
#     (behavior_sessions.session_type.str.contains('handoff_ready')) &
#     (behavior_sessions.genotype == 'wt/wt')]

# %%
subset_sessions.session_type.unique()
# Out:
# array(['TRAINING_4_images_G_training_7uL_reward',
#        'TRAINING_4_images_H_training_7uL_reward'], dtype=object)

# %%
len(subset_sessions)
# Out:
# 51

# %%
session_df = pd.DataFrame(columns = ['auc', 'evd', 'visual_index', 'timing_index' ,'strategy_index'])

# %%
for bsid in subset_sessions.index:

    print(f'\n Processing {bsid}')

    dir = f'local_modelfit/training4/{bsid}'
    os.makedirs(dir, exist_ok=True)

    plot_dir = f'plots/modelfit/training4/{bsid}'
    os.makedirs(plot_dir, exist_ok=True)
    
    behavior_session = cache.get_behavior_session(bsid)
    licks = behavior_session.licks
    licks_annot = get_metrics.annotate_licks(licks, behavior_session)
    stimulus_presentations = behavior_session.stimulus_presentations
    stimulus_presentations = stimulus_presentations[stimulus_presentations['active']]
    stim_table = get_metrics.annotate_bouts(licks_annot, stimulus_presentations)

    format_options = {
                    'preprocess': 2, 
                    'timing_params': [-5,4],
                    'num_cv_folds': 10}

    psydata = format_Xy.build_regressor(stim_table, format_options, behavior_session)

    strategy_list = ['task', 'timing1D', 'bias']


    format_Xy.visualize_design(psydata['full_df'], strategy_list, f'{plot_dir}/weight_mat', t_start = 1000)

    # # this is for other non-recording sessions // But handled already ! I think !
    # if np.sum(stimulus_presentations.omitted) == 0:
    #     strategy_list.remove('omissions')
    #     strategy_list.remove('omissions1')
    hyp, evd, wMode, credibleInt,weights = psy_funcs.fit_weights(psydata,strategy_list)
    # Save to .npy file
    np.save(f'{dir}/wMode.npy', wMode)
    ypred,ypred_each = psy_funcs.compute_ypred(psydata, wMode,weights)
    psy_funcs.plot_weights(wMode, weights,psydata,errorbar=credibleInt, ypred=ypred,
        filename=f"{plot_dir}/fit")
    print('Model Evidence:', evd)

    print("Cross Validation Analysis")
    cross_psydata = psy.trim(psydata, 
    END=int(np.floor(len(psydata['y'])/format_options['num_cv_folds'])\
    *format_options['num_cv_folds'])) 
    cross_results = psy_funcs.compute_cross_validation(cross_psydata, hyp, weights,
    folds=format_options['num_cv_folds'])
    cv_pred = psy_funcs.compute_cross_validation_ypred(cross_psydata, cross_results,ypred)
    auc = psy_funcs.compute_model_roc(psydata['y'],cv_pred,plot_this=True)

    print("Lesion Analysis")
    minus_task = strategy_list.copy()
    minus_task.remove('task')
    _, evd_minus_task, _, _, _ = psy_funcs.fit_weights(psydata,minus_task)
    minus_timing =  [s for s in strategy_list if 'timing' not in s]
    _, evd_minus_timing, _, _, _ = psy_funcs.fit_weights(psydata,minus_timing)
    # Calculate indices
    visual_index = utils.calculate_index(evd, evd_minus_task)
    timing_index = utils.calculate_index(evd, evd_minus_timing)
    # Calculate overall strategy index
    strategy_index = visual_index - timing_index

    print(f"Visual Index: {visual_index:.2f}%")
    print(f"Timing Index: {timing_index:.2f}%")
    print(f"Overall Strategy Index: {strategy_index:.2f}")

    # Determine dominant strategy
    dominant_strategy = "Visual" if strategy_index > 0 else "Timing"
    print(f"Dominant Strategy: {dominant_strategy}")

    # Create a new row with the calculated values
    new_row = pd.DataFrame({
        'auc': [auc],
        'evd': [evd],
        'visual_index': [visual_index],
        'timing_index': [timing_index],
        'strategy_index': [strategy_index]
    }, index=[bsid])

    # Append the new row to session_df
    session_df = pd.concat([session_df, new_row])
    
session_df.to_csv('local_modelfit/training4/strategy_summary.csv')
# Out:
#  Processing 1035340292
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -1344.9796979852254
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 5.72%
# Timing Index: 5.33%
# Overall Strategy Index: 0.40
# Dominant Strategy: Visual
#
#  Processing 1033820752
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -1072.6357840735946
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 3.81%
# Timing Index: 10.13%
# Overall Strategy Index: -6.33
# Dominant Strategy: Timing
#
#  Processing 1043159265
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -463.2692911304257
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 1.92%
# Timing Index: 5.20%
# Overall Strategy Index: -3.28
# Dominant Strategy: Timing
#
#  Processing 1045550754
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -1305.3642178685113
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 8.39%
# Timing Index: 17.86%
# Overall Strategy Index: -9.47
# Dominant Strategy: Timing
#
#  Processing 1051860415
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -1017.9663194690074
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 13.91%
# Timing Index: 4.89%
# Overall Strategy Index: 9.02
# Dominant Strategy: Visual
#
#  Processing 1057894268
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -1121.3295557473466
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 14.73%
# Timing Index: 14.01%
# Overall Strategy Index: 0.71
# Dominant Strategy: Visual
#
#  Processing 1056739437
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -1685.9141982360452
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 0.35%
# Timing Index: 29.42%
# Overall Strategy Index: -29.07
# Dominant Strategy: Timing
#
#  Processing 1056520886
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -1790.3456971079504
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 1.55%
# Timing Index: 21.31%
# Overall Strategy Index: -19.76
# Dominant Strategy: Timing
#
#  Processing 1057020839
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -1630.7406967325805
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 0.18%
# Timing Index: 28.83%
# Overall Strategy Index: -28.65
# Dominant Strategy: Timing
#
#  Processing 1057629370
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -1651.4545054992705
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 3.18%
# Timing Index: 21.73%
# Overall Strategy Index: -18.55
# Dominant Strategy: Timing
#
#  Processing 1058146470
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -684.7042367406393
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 27.54%
# Timing Index: 8.50%
# Overall Strategy Index: 19.04
# Dominant Strategy: Visual
#
#  Processing 1058478659
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -754.2683759408537
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 16.90%
# Timing Index: 5.41%
# Overall Strategy Index: 11.49
# Dominant Strategy: Visual
#
#  Processing 1061209141
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -1355.6948358679656
# Cross Validation Analysis
# running fold 9
# Lesion Analysis
# {'timing1D': 1, 'bias': 1}
# {'task': 1, 'bias': 1}
# Visual Index: 1.95%
# Timing Index: 15.75%
# Overall Strategy Index: -13.80
# Dominant Strategy: Timing
#
#  Processing 1059677668
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/hdmf/utils.py:668: UserWarning: Ignoring cached namespace 'core' version 2.6.0-alpha because version 2.7.0 is already loaded.
#   return func(args[0], **pargs)
# /opt/anaconda3/envs/swdb2024/lib/python3.9/site-packages/allensdk/brain_observatory/behavior/data_objects/metadata/subject_metadata/full_genotype.py:57: UserWarning: Unable to parse cre_line from full_genotype
#   warnings.warn('Unable to parse cre_line from full_genotype')
# /Users/xinzheng/Repos/swdb_2024_project/src_local/format_Xy.py:203: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.9, 1])
# {'task': 1, 'timing1D': 1, 'bias': 1}
# WARNING: sigDay has no effect, dayLength not supplied in dat
# Model Evidence: -339.5405621274258
# Cross Validation Analysis
# running fold 9

# %%
session_df.head()
# Out:
#                  auc          evd  visual_index  timing_index  omission_index  \
# 1050987699  0.771806 -1574.005946     16.518222      1.048066        0.009275
# 1050987699  0.771837 -1574.005946     16.518222      1.048066        0.009275
# 1071409009  0.767207 -1912.328603      1.967196      8.689973        0.189156
# 1071005395  0.824422 -1302.851271     13.302181     11.861270        0.262672
# 1077916733  0.822689 -1402.561742     12.236513      7.003457        0.085381
#
#             post_omission_index  strategy_index
# 1050987699             2.906920       15.470155
# 1050987699             2.906920       15.470155
# 1071409009             0.306505       -6.722777
# 1071005395             1.523181        1.440911
# 1077916733             3.898222        5.233056

# %%
fig, ax = plt.subplots(figsize=(10, 8))

# Create a scatter plot with points colored by strategy_index
scatter = ax.scatter(x=session_df.visual_index, 
                     y=session_df.timing_index, 
                     c=session_df.strategy_index, 
                     cmap='magma', 
                     s=100,  # Adjust point size if needed
                     alpha=1)  # Adjust transparency if needed

# Add colorbar
cbar = plt.colorbar(scatter)
cbar.set_label('Strategy Index', rotation=270, labelpad=15, fontsize = 14)

# Set labels and title
ax.set_xlabel('Visual Index', fontsize = 14)
ax.set_ylabel('Timing Index', fontsize = 14)
ax.set_title('Visual vs Timing Index', fontsize = 16)

# Add a diagonal line
max_val = max(ax.get_xlim()[1], ax.get_ylim()[1])
ax.plot([0, max_val], [0, max_val], 'k--', alpha=0.8)

# Adjust layout and display
plt.tight_layout()
plt.show()

# %%
len(session_df)
# Out:
# 55

# %%
subset_sessions = behavior_sessions[
    (behavior_sessions.session_type.str.contains('TRAINING_5')) & 
    (behavior_sessions.genotype == 'wt/wt')]

# %%
subset_sessions = behavior_sessions[
    (behavior_sessions.session_type.str.contains('TRAINING_5')) & 
    (behavior_sessions.session_type.str.contains('handoff_ready')) & 
    (behavior_sessions.genotype == 'wt/wt')]

# %%
subset_sessions
# Out:
#                     equipment_name genotype  mouse_id sex  age_in_days  \
# behavior_session_id
# 1039510310              BEH.B-Box4    wt/wt    524761   F          131
# 1038110210              BEH.B-Box1    wt/wt    524761   F          124
# 1038770408              BEH.B-Box1    wt/wt    524761   F          128
# 1037729598              BEH.B-Box1    wt/wt    524761   F          122
# 1037924499              BEH.B-Box1    wt/wt    524761   F          123
# ...                            ...      ...       ...  ..          ...
# 1131311228              BEH.G-Box6    wt/wt    585329   M          132
# 1132435788              BEH.G-Box6    wt/wt    585329   M          139
# 1132744410              BEH.G-Box6    wt/wt    585329   M          141
# 1135345527              BEH.G-Box6    wt/wt    585329   M          154
# 1135831584              BEH.G-Box6    wt/wt    585329   M          156
#
#                      session_number  prior_exposures_to_session_type  \
# behavior_session_id
# 1039510310                       33                                7
# 1038110210                       28                                2
# 1038770408                       30                                4
# 1037729598                       26                                0
# 1037924499                       27                                1
# ...                             ...                              ...
# 1131311228                       26                                4
# 1132435788                       31                                5
# 1132744410                       33                                7
# 1135345527                       42                                8
# 1135831584                       44                               10
#
#                      prior_exposures_to_image_set  \
# behavior_session_id
# 1039510310                                     16
# 1038110210                                     11
# 1038770408                                     13
# 1037729598                                      9
# 1037924499                                     10
# ...                                           ...
# 1131311228                                     19
# 1132435788                                     24
# 1132744410                                     26
# 1135345527                                     35
# 1135831584                                     37
#
#                      prior_exposures_to_omissions  ecephys_session_id  \
# behavior_session_id
# 1039510310                                      0                <NA>
# 1038110210                                      0                <NA>
# 1038770408                                      0                <NA>
# 1037729598                                      0                <NA>
# 1037924499                                      0                <NA>
# ...                                           ...                 ...
# 1131311228                                      0                <NA>
# 1132435788                                      0                <NA>
# 1132744410                                      0                <NA>
# 1135345527                                      0                <NA>
# 1135831584                                      0                <NA>
#
#                                   date_of_acquisition  \
# behavior_session_id
# 1039510310           2020-07-30 10:39:37.645000+00:00
# 1038110210           2020-07-23 10:37:39.982000+00:00
# 1038770408           2020-07-27 09:48:40.996000+00:00
# 1037729598           2020-07-21 10:36:01.421000+00:00
# 1037924499           2020-07-22 10:26:09.125000+00:00
# ...                                               ...
# 1131311228           2021-09-28 10:56:50.808000+00:00
# 1132435788           2021-10-05 10:44:22.073000+00:00
# 1132744410           2021-10-07 10:50:57.856000+00:00
# 1135345527           2021-10-20 10:08:26.696000+00:00
# 1135831584           2021-10-22 10:18:45.730000+00:00
#
#                                                      session_type image_set  \
# behavior_session_id
# 1039510310           TRAINING_5_images_G_handoff_ready_5uL_reward         G
# 1038110210           TRAINING_5_images_G_handoff_ready_5uL_reward         G
# 1038770408           TRAINING_5_images_G_handoff_ready_5uL_reward         G
# 1037729598           TRAINING_5_images_G_handoff_ready_5uL_reward         G
# 1037924499           TRAINING_5_images_G_handoff_ready_5uL_reward         G
# ...                                                           ...       ...
# 1131311228           TRAINING_5_images_H_handoff_ready_5uL_reward         H
# 1132435788           TRAINING_5_images_H_handoff_ready_5uL_reward         H
# 1132744410           TRAINING_5_images_H_handoff_ready_5uL_reward         H
# 1135345527           TRAINING_5_images_H_handoff_ready_5uL_reward         H
# 1135831584           TRAINING_5_images_H_handoff_ready_5uL_reward         H
#
#                      file_id
# behavior_session_id
# 1039510310              1251
# 1038110210              1252
# 1038770408              1255
# 1037729598              1269
# 1037924499              1270
# ...                      ...
# 1131311228              4246
# 1132435788              4250
# 1132744410              4251
# 1135345527              4255
# 1135831584              4256
#
# [222 rows x 14 columns]

# %%
subset_sessions
# Out:
#                     equipment_name genotype  mouse_id sex  age_in_days  \
# behavior_session_id
# 1039510310              BEH.B-Box4    wt/wt    524761   F          131
# 1038110210              BEH.B-Box1    wt/wt    524761   F          124
# 1038770408              BEH.B-Box1    wt/wt    524761   F          128
# 1037729598              BEH.B-Box1    wt/wt    524761   F          122
# 1037924499              BEH.B-Box1    wt/wt    524761   F          123
# ...                            ...      ...       ...  ..          ...
# 1131311228              BEH.G-Box6    wt/wt    585329   M          132
# 1132435788              BEH.G-Box6    wt/wt    585329   M          139
# 1132744410              BEH.G-Box6    wt/wt    585329   M          141
# 1135345527              BEH.G-Box6    wt/wt    585329   M          154
# 1135831584              BEH.G-Box6    wt/wt    585329   M          156
#
#                      session_number  prior_exposures_to_session_type  \
# behavior_session_id
# 1039510310                       33                                7
# 1038110210                       28                                2
# 1038770408                       30                                4
# 1037729598                       26                                0
# 1037924499                       27                                1
# ...                             ...                              ...
# 1131311228                       26                                4
# 1132435788                       31                                5
# 1132744410                       33                                7
# 1135345527                       42                                8
# 1135831584                       44                               10
#
#                      prior_exposures_to_image_set  \
# behavior_session_id
# 1039510310                                     16
# 1038110210                                     11
# 1038770408                                     13
# 1037729598                                      9
# 1037924499                                     10
# ...                                           ...
# 1131311228                                     19
# 1132435788                                     24
# 1132744410                                     26
# 1135345527                                     35
# 1135831584                                     37
#
#                      prior_exposures_to_omissions  ecephys_session_id  \
# behavior_session_id
# 1039510310                                      0                <NA>
# 1038110210                                      0                <NA>
# 1038770408                                      0                <NA>
# 1037729598                                      0                <NA>
# 1037924499                                      0                <NA>
# ...                                           ...                 ...
# 1131311228                                      0                <NA>
# 1132435788                                      0                <NA>
# 1132744410                                      0                <NA>
# 1135345527                                      0                <NA>
# 1135831584                                      0                <NA>
#
#                                   date_of_acquisition  \
# behavior_session_id
# 1039510310           2020-07-30 10:39:37.645000+00:00
# 1038110210           2020-07-23 10:37:39.982000+00:00
# 1038770408           2020-07-27 09:48:40.996000+00:00
# 1037729598           2020-07-21 10:36:01.421000+00:00
# 1037924499           2020-07-22 10:26:09.125000+00:00
# ...                                               ...
# 1131311228           2021-09-28 10:56:50.808000+00:00
# 1132435788           2021-10-05 10:44:22.073000+00:00
# 1132744410           2021-10-07 10:50:57.856000+00:00
# 1135345527           2021-10-20 10:08:26.696000+00:00
# 1135831584           2021-10-22 10:18:45.730000+00:00
#
#                                                      session_type image_set  \
# behavior_session_id
# 1039510310           TRAINING_5_images_G_handoff_ready_5uL_reward         G
# 1038110210           TRAINING_5_images_G_handoff_ready_5uL_reward         G
# 1038770408           TRAINING_5_images_G_handoff_ready_5uL_reward         G
# 1037729598           TRAINING_5_images_G_handoff_ready_5uL_reward         G
# 1037924499           TRAINING_5_images_G_handoff_ready_5uL_reward         G
# ...                                                           ...       ...
# 1131311228           TRAINING_5_images_H_handoff_ready_5uL_reward         H
# 1132435788           TRAINING_5_images_H_handoff_ready_5uL_reward         H
# 1132744410           TRAINING_5_images_H_handoff_ready_5uL_reward         H
# 1135345527           TRAINING_5_images_H_handoff_ready_5uL_reward         H
# 1135831584           TRAINING_5_images_H_handoff_ready_5uL_reward         H
#
#                      file_id
# behavior_session_id
# 1039510310              1251
# 1038110210              1252
# 1038770408              1255
# 1037729598              1269
# 1037924499              1270
# ...                      ...
# 1131311228              4246
# 1132435788              4250
# 1132744410              4251
# 1135345527              4255
# 1135831584              4256
#
# [222 rows x 14 columns]

# %%
subset_sessions['session_type'].unique()
# Out:
# array(['TRAINING_5_images_G_epilogue_5uL_reward',
#        'TRAINING_5_images_G_handoff_ready_5uL_reward',
#        'TRAINING_5_images_G_handoff_lapsed_5uL_reward',
#        'TRAINING_5_images_H_handoff_ready_5uL_reward',
#        'TRAINING_5_images_H_epilogue_5uL_reward',
#        'TRAINING_5_images_H_handoff_lapsed_5uL_reward'], dtype=object)
